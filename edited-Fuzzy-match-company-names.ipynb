# %% [markdown]
# # Finding similar company name and auto matching them -  editted pr450
#
# This program will use NLP and ML technique to match similar company names. Matching form common words like "LTD" and "COMPANY" will be discounted autometically in the algorithm.
#
# Library used:
# * pandas
# * fuzzywuzzy

# %% [markdown]
# ## Load the table in pandas DataFrame
#
# Data later deleted but found on http://download.companieshouse.gov.uk/en_output.html *(the version shown here is snapshot of June 2020)*

# %%
import pandas as pd
pd.set_option('display.max_columns', 1000)
import os
os.chdir("/home/puria-radmard/Repos/VectorAI2020/fuzzy-match-company-name")
print("CP 1")
df = pd.read_csv("BasicCompanyDataAsOneFile-2020-06-01.csv", sep='\t')
print("CP 2")
df.head()

# Open up the csv which we will work with. 2.2GB so later deleted to allow commits
# Out:
# CP 1

# %%
df.columns

# All features by which companies are described wtih in the dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-03e52e12f3a6> in <module>
# ----> 1 df.columns
#       2
#       3 # All features by which companies are described wtih in the dataset
#
# NameError: name 'df' is not defined

# %%
df['RegAddress.PostTown'].value_counts().head(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a510cba6b2de> in <module>
# ----> 1 df['RegAddress.PostTown'].value_counts().head(30)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Frequency of words
# Since we have lots of companies, we will only use companies in Cambridge as an example.
#
# First we find the 30 most common words in all company names. As we will be expecting them to be repeating a lot even in companies that is not the same, we cannot match company names using them. The way we do it is we will deduct the matching score of a pair if any keywords is present in the names.

# %%
from collections import Counter
all_names = df['CompanyName'][df['RegAddress.PostTown']=='CAMBRIDGE'].unique()
names_freq = Counter()
for name in all_names:
    names_freq.update(str(name).split(" "))
key_words = [word for (word,_) in names_freq.most_common(30)]
print(key_words)
# Out:
# ['LIMITED', 'LTD', 'CAMBRIDGE', 'SERVICES', 'MANAGEMENT', '&', 'COMPANY', 'THE', 'CONSULTING', 'LTD.', 'SOLUTIONS', 'AND', 'PROPERTY', 'UK', 'LLP', '(CAMBRIDGE)', 'CONSULTANCY', 'GROUP', 'HOLDINGS', 'CONSULTANTS', 'ASSOCIATES', 'COMPOSITES', 'ENGINEERING', 'DEVELOPMENTS', 'INTERNATIONAL', 'OF', 'DESIGN', 'TECHNOLOGY', 'PROPERTIES', '(UK)']

# %%
len(all_names)
# Out:
# 15889

# %% [markdown]
# ## Matching by Grouping
# Then we group the names by their 1st character. As the list is too long, it will take forever to match them all at once (15889 x 15889 pairs to consider). The work around is to match them by groups, assuming if the names are not matched at the 1st character, it is unlikely that they are the same name.

# %%
all_main_name = pd.DataFrame(columns=['sort_gp','names','alias','score'])
all_names.sort()
all_main_name['names'] = all_names
all_main_name['sort_gp'] = all_main_name['names'].apply(lambda x: x[0])

# %% [markdown]
# ## Fuzzy Matching
# Here for each group, we use `fuzzywuzzy.token_sort_ratio` to matching the names. Different form the basic `fuzzywuzzy.ratio` which use Levenshtein Distance to calculate the differences, it allow the token (words) in a name to swap order and still give a 'perfect' match. (ref: https://github.com/seatgeek/fuzzywuzzy)

# %%
from fuzzywuzzy import fuzz

all_sort_gp = all_main_name['sort_gp'].unique()

def no_key_word(name):
    """check if the name contain the keywords in travel company"""
    output = True
    for key in key_words:
        if key in name:
            output = False
    return output

for sortgp in all_sort_gp:
    this_gp = all_main_name.groupby(['sort_gp']).get_group(sortgp)
    gp_start = this_gp.index.min()
    gp_end = this_gp.index.max()
    for i in range(gp_start,gp_end+1):
    
        # if self has not got alias, asign to be alias of itself
        if pd.isna(all_main_name['alias'].iloc[i]):
            all_main_name['alias'].iloc[i] = all_main_name['names'].iloc[i]
            all_main_name['score'].iloc[i] = 100
        
        # if the following has not got alias and fuzzy match, asign to be alias of this one
        for j in range(i+1,gp_end+1):
            if pd.isna(all_main_name['alias'].iloc[j]):
                fuzz_socre = fuzz.token_sort_ratio(all_main_name['names'].iloc[i],all_main_name['names'].iloc[j])
                if not no_key_word(all_main_name['names'].iloc[j]):
                    fuzz_socre -= 10
                if (fuzz_socre > 85):
                    all_main_name['alias'].iloc[j] = all_main_name['alias'].iloc[i]
                    all_main_name['score'].iloc[j] = fuzz_socre
                    
        if i % (len(all_names)//10) == 0:
            print("progress: %.2f" % (100*i/len(all_names)) + "%")
                
all_main_name.to_csv('company_in_cambridge.csv')
# Out:
# progress: 0.00%
# progress: 9.99%
# progress: 19.99%
# progress: 29.98%
# progress: 39.98%
# progress: 49.97%
# progress: 59.97%
# progress: 69.96%
# progress: 79.95%
# progress: 89.95%
# progress: 99.94%

# %%
all_main_name[(all_main_name['names']!=all_main_name['alias']) & (all_main_name['alias'].notna())]
# Out:
#       sort_gp                                              names  \
# 761         A                                     AMADEUS EII LP
# 762         A                                    AMADEUS EIII LP
# 763         A                                      AMADEUS HI LP
# 766         A                                     AMADEUS II 'A'
# 767         A                                     AMADEUS II 'B'
# 768         A                                     AMADEUS II 'C'
# 769         A                                        AMADEUS III
# 773         A                   AMADEUS IV EARLY STAGE FUND B LP
# 776         A                                      AMADEUS JI LP
# 777         A                                      AMADEUS LI LP
# 783         A                                      AMADEUS TI LP
# 937         A                            ANP ENGINEERING LIMITED
# 1361        A                                      AVITO LIMITED
# 1607        B                            BCK INVESTMENTS LIMITED
# 1849        B                                    BIRDY FILMS LTD
# 1971        B               BLUESTONE CAPITAL MANAGEMENT LIMITED
# 1976        B           BLUESTONE MORTGAGE FINANCE NO. 4 LIMITED
# 1977        B            BLUESTONE MORTGAGE FINANCE NO.2 LIMITED
# 2698        C               CAMBRIDGE DESIGN PARTNERSHIP LIMITED
# 2839        C                          CAMBRIDGE H C 102 LIMITED
# 2840        C                          CAMBRIDGE H C 129 LIMITED
# 2911        C   CAMBRIDGE INTERNATIONAL EDUCATION CENTRE LIMITED
# 3142        C         CAMBRIDGE RESEARCH AND ENGINEERING LIMITED
# 3184        C   CAMBRIDGE SEMINARS INTERNATIONAL COLLEGE LIMITED
# 3566        C               CASA MIA DEVELOPMENTS (NO 3) LIMITED
# 4159        C                COLLEGE COURT (CAMBRIDGE B) LIMITED
# 4944        D                       DGP ENGINEERING SERVICES LTD
# 5182        D                  DS ELECTRICAL (CAMBRIDGE) LIMITED
# 6220        F                       FRAZER STANNARD PROPERTY LTD
# 6407        G           GATEWAY (218) MANAGEMENT COMPANY LIMITED
# 6517        G                                       GFB AERO LTD
# 6951        H                HAMMER AND TONG PRODUCTIONS LIMITED
# 7354        H                           HPG DEVELOPMENTS LIMITED
# 7811        I                              IQ CAPITAL FUND II LP
# 7812        I                           IQ CAPITAL FUND III C LP
# 7813        I                             IQ CAPITAL FUND III LP
# 7817        I                     IQ CAPITAL PARTNERS GP III LLP
# 8420        K  KEW BRIDGE WEST 2 RESIDENTS MANAGEMENT COMPANY...
# 8421        K  KEW BRIDGE WEST 3 RESIDENTS MANAGEMENT COMPANY...
# 9772        M                           MILLERS PARTNERS LIMITED
# 11225       P                        PIGEON HUNSTANTON 2 LIMITED
# 11711       Q          QQ2 RESIDENTS PROPERTY MANAGEMENT LIMITED
# 12129       R  RIDGEMOND PARK (BLOCK 4) MANAGEMENT COMPANY LI...
# 12156       R                           RINDL CONSULTING LIMITED
# 12523       S                              SANDFORD AVIATION LTD
# 12807       S                    SHAWS OF CAMBRIDGE (EH) LIMITED
# 12902       S   SILKWORKS RESIDENTS MANAGEMENT COMPANY 3 LIMITED
# 13499       S                       STOW HEALTHCARE (FP) LIMITED
# 13865       T                                       TCOM LIMITED
# 14116       T                               THE CUWBC FOUNDATION
# 14149       T            THE EXETER TRUSTEE COMPANY NO.2 LIMITED
# 14343       T                THE PROCUREMENT PARTNERSHIP LIMITED
# 14702       T                         TRANQUILLITY PARKS LIMITED
# 14816       T                           TSANG CONSULTING LIMITED
# 15340       W                      WATER LANE 3 NOMINEES LIMITED
# 15349       W         WATERBEACH NO.1 MANAGEMENT COMPANY LIMITED
# 15667       W                 WRENBRIDGE (CHEDDARS LANE) LIMITED
#
#                                                    alias  score
# 761                                        AMADEUS EI LP     96
# 762                                        AMADEUS EI LP     93
# 763                                        AMADEUS EI LP     92
# 766                                            AMADEUS I     86
# 767                                            AMADEUS I     86
# 768                                            AMADEUS I     86
# 769                                            AMADEUS I     90
# 773                     AMADEUS IV EARLY STAGE FUND A LP     94
# 776                                        AMADEUS EI LP     92
# 777                                        AMADEUS EI LP     92
# 783                                        AMADEUS PI LP     92
# 937                              AMP ENGINEERING LIMITED     86
# 1361                                      AVIATO LIMITED     86
# 1607                         BCK INVESTMENTS (2) LIMITED     86
# 1849                                      BIRD FILMS LTD     87
# 1971             BLUESTONE CAPITAL MANAGEMENT II LIMITED     86
# 1976            BLUESTONE MORTGAGE FINANCE NO. 3 LIMITED     87
# 1977            BLUESTONE MORTGAGE FINANCE NO. 3 LIMITED     87
# 2698           CAMBRIDGE DESIGN PARTNERSHIP (UK) LIMITED     86
# 2839                           CAMBRIDGE H C 100 LIMITED     86
# 2840                           CAMBRIDGE H C 100 LIMITED     86
# 2911    CAMBRIDGE EDUCATION INTERNATIONAL CENTER LIMITED     88
# 3142          CAMBRIDGE ENGINEERING AND RESEARCH LIMITED     90
# 3184        CAMBRIDGE INTERNATIONAL SEMINARS COLLEGE LTD     86
# 3566                CASA MIA DEVELOPMENTS (NO 1) LIMITED     87
# 4159                 COLLEGE COURT (CAMBRIDGE A) LIMITED     87
# 4944                         DG ENGINEERING SERVICES LTD     88
# 5182                  DBS ELECTRICAL (CAMBRIDGE) LIMITED     88
# 6220                        FRASER STANNARD PROPERTY LTD     86
# 6407            GATEWAY (216) MANAGEMENT COMPANY LIMITED     87
# 6517                                         GB AERO LTD     86
# 6951               HAMMER AND THONGS PRODUCTIONS LIMITED     87
# 7354                            HP3 DEVELOPMENTS LIMITED     86
# 7811                                IQ CAPITAL FUND I LP     98
# 7812                                IQ CAPITAL FUND I LP     91
# 7813                                IQ CAPITAL FUND I LP     95
# 7817                    IQ CAPITAL PARTNERS GP III C LLP     87
# 8420   KEW BRIDGE WEST 1 RESIDENTS MANAGEMENT COMPANY...     88
# 8421   KEW BRIDGE WEST 1 RESIDENTS MANAGEMENT COMPANY...     88
# 9772                             MILLER PARTNERS LIMITED     88
# 11225                        PIGEON HUNSTANTON 1 LIMITED     86
# 11711          QQ1 RESIDENTS PROPERTY MANAGEMENT LIMITED     88
# 12129  RIDGEMOND PARK (BLOCK 3) MANAGEMENT COMPANY LI...     88
# 12156                             RIL CONSULTING LIMITED     86
# 12523                             SANDFORD AVIAITION LTD     88
# 12807                    SHAWS OF CAMBRIDGE (EB) LIMITED     87
# 12902   SILKWORKS RESIDENTS MANAGEMENT COMPANY 2 LIMITED     88
# 13499                       STOW HEALTHCARE (BP) LIMITED     86
# 13865                                        TCO LIMITED     86
# 14116                                THE CUBC FOUNDATION     87
# 14149           THE EXETER TRUSTEE COMPANY NO. 1 LIMITED     87
# 14343                   THE PROCUREMENT PARTNERS LIMITED     86
# 14702                          TRANQUILITY PARKS LIMITED     88
# 14816                             TAG CONSULTING LIMITED     86
# 15340                      WATER LANE 2 NOMINEES LIMITED     87
# 15349        WATERBEACH NO. 2 MANAGEMENT COMPANY LIMITED     88
# 15667               WRENBRIDGE (CHEDDARS LANE 2) LIMITED     87

# %% [markdown]
# The result is saved in a csv file locally for future inspection and further experimentation. Inspecting the result, the matches consisted of 3 groups:
#
# 1. they are usually differ in spelling by 1 character: missing an 'L' or 'I' or 'S'
# 2. highly similar names: 'No.3' instead of 'No.2' or 'EB' instread of 'EH'
# 3. fairly similar names: 'HAMMER AND THONGS PRODUCTIONS LIMITED' and 'HAMMER AND TONG PRODUCTIONS LIMITED'
#
# For type 1 and 2 matches it could be the same company, the diffeernce in names could be an intentional alteration or simply a typo. But it is not likely the same company for type 3 matched, it seems more like a coincidnce.
#
# To further confirm, manual work need to be done but this program saves a lot of manual work hours.

# %%
all_main_name[(all_main_name['names']!=all_main_name['alias']) & (all_main_name['alias'].notna())].shape[0]
# Out:
# 57

# %%
len(all_main_name['alias'].unique())
# Out:
# 15832

# %% [markdown]
# By applying the fuzzy matching, 57 names are caught similar to another name, which is less then 1% of the total. By using this program names that need checking drastically reduce form 15889 total to only 57.
